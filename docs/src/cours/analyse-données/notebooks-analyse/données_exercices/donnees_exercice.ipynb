# %% [markdown]
# # Données exercices

# %% [markdown]
# Entrainez vous à faire des analyses en composantes principales sur ces divers jeux de données. Il y a otujours une petite interprétation à faire.

# %%
import pandas

# %% [markdown]
# ## Vieilles gloires du tennis

# %%
tennis = pandas.read_csv('tennis.csv', index_col=0)

# %%
tennis
# Out:
#              Coup_Droit  Revers  Service  Vole  Retour  Smash  Jeu_de_jambe  \
# ARIAS               8.0     5.0      3.0   2.0     6.0    3.0           6.0
# BECKER              8.0     7.0     10.0   8.0     7.0    9.0           6.0
# BORG               10.0     9.0      7.0   5.0     9.0    9.0          10.0
# CARLSSON            6.0     5.0      2.0   2.0     6.0    2.0           6.0
# CASH                5.0     4.0      6.0   7.0     5.0    7.0           6.0
# CLERC               7.0     6.0      4.0   3.0     5.0    3.0           6.0
# CONNORS             7.0    10.0      4.0   6.0    10.0    7.0           9.0
# CURREN              4.0     4.0      8.0   7.0     6.0    6.0           5.0
# EDBERG              5.0     8.0      8.0   8.0     6.0    6.0           6.0
# FORGET              7.0     4.0      6.0   5.0     5.0    5.0           5.0
# GERULAITIS          6.0     5.0      6.0  10.0     4.0    6.0           8.0
# ...

# %% [markdown]
# ## Prix nobels

# %% [markdown]
# Répartitions des prix nobels par pays jusqu'en 2010.

# %%
nobels = pandas.read_csv('nobels.csv', index_col=0)

# %%
nobels
# Out:
#              Autriche  Pays-bas  Grande-Bretagne  Allemagne  Suisse  Suede  \
# physique            3         8               24         18       4      4
# medecine            5         3               24         15       6      7
# economie            0         1                6          1       0      2
# chimie              1         3               24         26       6      4
# litterature         1         0               10          8       0      6
# paix                2         1               13          5       7      5
#
#              Belgique  Danemark  Russie  Italie  Norvege  France  USA  Japon  \
# physique            0         3       8       3        0      11   70      3
# medecine            4         5       2       4        0       8   85      1
# economie            0         0       1       0        3       1   37      0
# chimie              1         2       1       1        1       8   55      4
# ...

# %% [markdown]
# ## Patrimoine

# %% [markdown]
# Répartition du patrimoine selon les catégories socio-professionnelles.
#
# En ligne :
# - Anciens indépendants non agricoles (AI)
# - Professions libérales (PL)
# - Industriels, artisans commerçants (IAC)
# - Cadres supérieurs (CS)
# - Agriculteurs (AG)
# - Anciens agriculteurs (AA)
# - Anciens salariés (AS)
# - Professions intermédiaires (PI)
# - Employés (EM)
# - Ouvriers (OU)
#
# En colonnes :
# - Livrets logement bons,... (LIV)
# - assurances (ELB)
# - placements (POA)
# - actions (ACT)
# - Pierre (PIE)
# - terres (TER)

# %%
patrimoine = pandas.read_csv('patrimoine.csv', index_col=0)

# %%
patrimoine
# Out:
#       LIV   ELB   POA   ACT   PIE   TER
# AI    8.0   6.0  10.0  23.0  44.0   9.0
# PL    6.0   8.0  17.0  25.0  35.0   9.0
# IAC   5.0   6.0  13.0  36.0  34.0   6.0
# CS    9.0   9.0  14.0  40.0  23.0   5.0
# AG   11.0  13.0  16.0   7.0  19.0  34.0
# AA   14.0  13.0  13.0   6.0  27.0  27.0
# AS   16.0  14.0  13.0  25.0  26.0   6.0
# PI   17.0  15.0  17.0  20.0  26.0   5.0
# EM   22.0  14.0  18.0  11.0  27.0   8.0
# OU   24.0  18.0  25.0   8.0  20.0   5.0

# %% [markdown]
# ## Les Bœufs

# %% [markdown]
# Vous allez étudier la distribution de poids de différentes parties
# d'un groupe de 23 bovins.
#
# Les différents axes correspondent à :
#
# * 0 : poids vif,
# * 1 : poids de la carcasse,
# * 2 : poids de la viande de première qualité,
# * 3 : poids de la viande totale,
# * 4 : poids du gras,
# * 5 : poids des os.
#
# Mettez vous dans la peau d'un boucher et c'est parti !

# %%
boeufs = pandas.read_csv('boeufs.csv', index_col=0)

# %%
boeufs
# Out:
#       0    1     2     3     4     5
# 0   395  224  35.1  79.1   6.0  14.9
# 1   410  232  31.9  73.4   8.7  16.4
# 2   405  233  30.7  76.5   7.0  16.5
# 3   405  240  30.4  75.3   8.7  16.0
# 4   390  217  31.9  76.5   7.8  15.7
# 5   415  243  32.1  77.4   7.1  18.5
# 6   390  229  32.1  78.4   4.6  17.0
# 7   405  240  31.1  76.5   8.2  15.3
# 8   420  234  32.4  76.0   7.2  16.8
# 9   390  223  33.8  77.0   6.2  16.8
# 10  415  247  30.7  75.5   8.4  16.1
# 11  400  234  31.7  77.6   5.7  18.7
# 12  400  224  28.2  73.5  11.0  15.5
# 13  395  229  29.4  74.5   9.3  16.1
# 14  395  219  29.7  72.8   8.7  18.5
# 15  395  224  28.5  73.7   8.7  17.3
# 16  400  223  28.5  73.1   9.1  17.7
# 17  400  224  27.8  73.2  12.2  14.6
# 18  400  221  26.5  72.3  13.2  14.5
# 19  410  233  25.9  72.3  11.1  16.6
# 20  402  234  27.1  72.1  10.4  17.5
# 21  400  223  26.8  70.3  13.5  16.2
# 22  400  213  25.8  70.4  12.1  17.5

# %% [markdown]
# ## Liens entre données openstreetmap et richesses d'un pays

# %% [markdown]
# **tiré de là** : https://janakiev.com/blog/osm-predict-economic-indicators/
#
#
# Indices économiques de pays européens (https://fr.wikipedia.org/wiki/Liste_des_pays_d%27Europe_par_superficie)
#
# Croisez les deux bases de données suivantes :
#
# * indices économiques : https://github.com/njanakiev/osm-predict-economic-measurements/blob/master/data/economic_measurements.csv
# * indicateurs d'openstreetmap : https://github.com/njanakiev/osm-predict-economic-measurements/blob/master/data/country_amenity_counts.csv
#
# Pour en faire une unique base de données. Puis faites une ACP pour interpréter celle-ci.
