# %% [markdown]
# # Création données géographiques
#
# > TBD : à rendre plus digeste

# %% [markdown]
# * graphML, json
# * créer un graphe à partir du csv
#
# * format matrice, liste d'adjacence, dictionnaire : attentoin aux complexités
# * représentation grpahique du graphe des villes

# %% [markdown]
# ## format de graphes
#
# plusieurs concurents :
# * [networkx](https://networkx.org/documentation/stable//reference/readwrite/index.html) en propose plusieurs
# * [json graph](https://github.com/jsongraph/json-graph-specification)
# * à la main.
#
# Attention aux complexités, la structure va influer sur la rapidité des opérations.

# %% [markdown]
# ## csv vers graphe
#
# On va charger le fichier des villes française puis créer un point avec les coordonnées. On va procéder comme dans le [tutoriel](https://geopandas.org/gallery/create_geopandas_from_pandas.html).
#
# On utilise [geopandas.read_file](https://geopandas.org/docs/reference/api/geopandas.read_file.html#geopandas-read-file)

# %%
import geopandas as gpd
import pandas as pd

# %%
df = pd.read_csv("./villes_france_30000.csv")

# %%
df
# Out:
#          idx  INSEE          nom  latitude  longitude  population
# 0          1  75100        Paris    48.867      2.333     2152423
# 1          2  13200    Marseille    43.300      5.400      800550
# 2          3  69380         Lyon    45.750      4.850      415487
# 3          4  31555     Toulouse    43.600      1.433      358688
# 4          5   6088         Nice    43.700      7.250      342439
# ...      ...    ...          ...       ...        ...         ...
# 29995  29996  52195   Farincourt    47.700      5.683          68
# 29996  29997  70090   Boursieres    47.617      6.050          68
# 29997  29998  54224  Germonville    48.400      6.217          68
# 29998  29999  73049  Bonvillaret    45.567      6.300          68
# 29999  30000  70398     Ormoiche    47.800      6.317          68
#
# [30000 rows x 6 columns]

# %%
df.dtypes
# Out:
# idx             int64
# INSEE           int64
# nom            object
# latitude      float64
# longitude     float64
# population      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['idx', 'INSEE', 'nom', 'latitude', 'longitude', 'population'], dtype='object')

# %% [markdown]
# On crée la geometry en disant que c'est un point, et on place le crs à ce qu'il faut.

# %%
villes = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
villes.set_crs("EPSG:4326")
# Out:
#          idx  INSEE          nom  latitude  longitude  population  \
# 0          1  75100        Paris    48.867      2.333     2152423
# 1          2  13200    Marseille    43.300      5.400      800550
# 2          3  69380         Lyon    45.750      4.850      415487
# 3          4  31555     Toulouse    43.600      1.433      358688
# 4          5   6088         Nice    43.700      7.250      342439
# ...      ...    ...          ...       ...        ...         ...
# 29995  29996  52195   Farincourt    47.700      5.683          68
# 29996  29997  70090   Boursieres    47.617      6.050          68
# 29997  29998  54224  Germonville    48.400      6.217          68
# 29998  29999  73049  Bonvillaret    45.567      6.300          68
# 29999  30000  70398     Ormoiche    47.800      6.317          68
#
#                        geometry
# 0      POINT (2.33300 48.86700)
# 1      POINT (5.40000 43.30000)
# 2      POINT (4.85000 45.75000)
# 3      POINT (1.43300 43.60000)
# 4      POINT (7.25000 43.70000)
# ...                         ...
# 29995  POINT (5.68300 47.70000)
# 29996  POINT (6.05000 47.61700)
# 29997  POINT (6.21700 48.40000)
# 29998  POINT (6.30000 45.56700)
# 29999  POINT (6.31700 47.80000)
#
# [30000 rows x 7 columns]

# %% [markdown]
# Attention, le [code insee](https://fr.wikipedia.org/wiki/Code_officiel_g%C3%A9ographique) n'est pas le code postal.

# %%
villes[villes["nom"] == "Marseille"]
# Out:
#    idx  INSEE        nom  latitude  longitude  population  \
# 1    2  13200  Marseille      43.3        5.4      800550
#
#                    geometry
# 1  POINT (5.40000 43.30000)

# %%
villes.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# garder les geandes villes :

# %%
villes[villes.population >= 50000].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Supprimer l'ile de France mais pas Paris avec [bbox tool](http://norbertrenner.de/osm/bbox.html) :

# %%
from shapely.geometry import Polygon

# %%
ile_de_france = Polygon([(1.965, 48.62), (1.965, 49.067), (2.899, 49.067), (2.899, 48.62)])

# %%
villes[villes.geometry.within(ile_de_france)]
# Out:
#          idx  INSEE                   nom  latitude  longitude  population  \
# 0          1  75100                 Paris    48.867      2.333     2152423
# 34        35  92012  Boulogne-Billancourt    48.833      2.250      101743
# 37        38  93048             Montreuil    48.867      2.433       94754
# 39        40  95018            Argenteuil    48.950      2.250       93096
# 40        41  93066           Saint-Denis    48.933      2.358       89988
# ...      ...    ...                   ...       ...        ...         ...
# 28639  28640  95633           Vaudherland    49.000      2.483          93
# 28640  28641  77193                Forfry    49.050      2.850          93
# 29306  29307  95212    Epiais-les-Louvres    49.033      2.550          80
# 29359  29360  78917                Rhodon    48.717      2.067          79
# 29365  29366  95492      LePlessis-Gassot    49.033      2.417          79
#
#                        geometry
# 0      POINT (2.33300 48.86700)
# 34     POINT (2.25000 48.83300)
# 37     POINT (2.43300 48.86700)
# 39     POINT (2.25000 48.95000)
# 40     POINT (2.35800 48.93300)
# ...                         ...
# 28639  POINT (2.48300 49.00000)
# 28640  POINT (2.85000 49.05000)
# 29306  POINT (2.55000 49.03300)
# 29359  POINT (2.06700 48.71700)
# 29365  POINT (2.41700 49.03300)
#
# [425 rows x 7 columns]

# %%
villes[(~villes.geometry.within(ile_de_france)) | (villes["nom"] == "Paris")]
# Out:
#          idx  INSEE          nom  latitude  longitude  population  \
# 0          1  75100        Paris    48.867      2.333     2152423
# 1          2  13200    Marseille    43.300      5.400      800550
# 2          3  69380         Lyon    45.750      4.850      415487
# 3          4  31555     Toulouse    43.600      1.433      358688
# 4          5   6088         Nice    43.700      7.250      342439
# ...      ...    ...          ...       ...        ...         ...
# 29995  29996  52195   Farincourt    47.700      5.683          68
# 29996  29997  70090   Boursieres    47.617      6.050          68
# 29997  29998  54224  Germonville    48.400      6.217          68
# 29998  29999  73049  Bonvillaret    45.567      6.300          68
# 29999  30000  70398     Ormoiche    47.800      6.317          68
#
#                        geometry
# 0      POINT (2.33300 48.86700)
# 1      POINT (5.40000 43.30000)
# 2      POINT (4.85000 45.75000)
# 3      POINT (1.43300 43.60000)
# 4      POINT (7.25000 43.70000)
# ...                         ...
# 29995  POINT (5.68300 47.70000)
# 29996  POINT (6.05000 47.61700)
# 29997  POINT (6.21700 48.40000)
# 29998  POINT (6.30000 45.56700)
# 29999  POINT (6.31700 47.80000)
#
# [29576 rows x 7 columns]

# %%
villes[(~villes.geometry.within(ile_de_france)) | (villes["nom"] == "Paris")].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## distance puis graphe

# %%
villes.buffer(10)
# Out:
# 0        POLYGON ((12.33300 48.86700, 12.28485 47.88683...
# 1        POLYGON ((15.40000 43.30000, 15.35185 42.31983...
# 2        POLYGON ((14.85000 45.75000, 14.80185 44.76983...
# 3        POLYGON ((11.43300 43.60000, 11.38485 42.61983...
# 4        POLYGON ((17.25000 43.70000, 17.20185 42.71983...
#                                ...
# 29995    POLYGON ((15.68300 47.70000, 15.63485 46.71983...
# 29996    POLYGON ((16.05000 47.61700, 16.00185 46.63683...
# 29997    POLYGON ((16.21700 48.40000, 16.16885 47.41983...
# 29998    POLYGON ((16.30000 45.56700, 16.25185 44.58683...
# 29999    POLYGON ((16.31700 47.80000, 16.26885 46.81983...
# Length: 30000, dtype: geometry

# %%
MAX_DIST = 1
graphe = villes[villes.population >= 10000]

g = {nom: {} for nom in graphe.nom}

prev = None
for i in range(len(graphe)):
    dist = graphe.iloc[i+1:].distance(graphe.iloc[i].geometry)
    for j, d in enumerate(dist):
        if d < MAX_DIST:
            g[graphe.iloc[i].nom][graphe.iloc[i + j + 1].nom] = {"weight": d}
            g[graphe.iloc[i + j + 1].nom][graphe.iloc[i].nom] = {"weight": d}

    if (int(i / len(graphe) * 100) % 10 == 0) and (int(i / len(graphe) * 100) != prev):
        prev = int(i / len(graphe) * 100)
        print(str(prev)+"% effectué")
# Out:
# 0% effectué
# 10% effectué
# 20% effectué
# 30% effectué
# 40% effectué
# 50% effectué
# 60% effectué
# 70% effectué
# 80% effectué
# 90% effectué

# %%
len(g)
# Out:
# 787

# %%
sum(len(g[x]) for x in g)
# Out:
# 76448

# %% [markdown]
# Conversion du graphe dictionnaire en graphe de [networkx](https://networkx.org/documentation/stable/index.html)

# %%
import networkx as nx
G = nx.from_dict_of_dicts(g)

# %%
len(G)
# Out:
# 787

# %%
print(G["Paris"])
# Out:
# {'Boulogne-Billancourt': {'weight': 0.08969392398596439}, 'Montreuil': {'weight': 0.09999999999999964}, 'Argenteuil': {'weight': 0.11737972567697091}, 'Saint-Denis': {'weight': 0.07057619995437786}, 'Versailles': {'weight': 0.21092415698539627}, 'Nanterre': {'weight': 0.13703284277865685}, 'Vitry-sur-Seine': {'weight': 0.10744766167767127}, 'Aulnay-sous-Bois': {'weight': 0.2018539075668361}, 'Creteil': {'weight': 0.15815182578775153}, 'Champigny-sur-Marne': {'weight': 0.19067249408344042}, 'Colombes': {'weight': 0.09689685237406041}, 'Saint-Maur-des-Fosses': {'weight': 0.1799388785115656}, 'Aubervilliers': {'weight': 0.07071067811865764}, 'Rueil-Malmaison': {'weight': 0.13395894893585936}, 'Neuilly-sur-Seine': {'weight': 0.06791170738540012}, 'Drancy': {'weight': 0.13433167906342988}, 'Antony': {'weight': 0.12156479753612638}, 'Sarcelles': {'weight': 0.1420880009008526}, 'Beauvais': {'weight': 0.6187535858481976}, 'Noisy-le-Grand': {'weight': 0.2346167086973983}, 'Ivry-sur-Seine': {'weight': 0.07071067811865261}, 'Maisons-Alfort': {'weight': 0.12037026210821322}, 'Fontenay-sous-Bois': {'weight': 0.15096025967121227}, 'Sartrouville': {'weight': 0.1714322023425034}, 'Epinay-sur-Seine': {'weight': 0.08668333173108272}, 'Sevran': {'weight': 0.21060864179800465}, 'Villejuif': {'weight': 0.07513321502504741}, 'Meaux': {'weight': 0.5404118799582414}, 'Cergy': {'weight': 0.31354744457577916}, 'Clichy': {'weight': 0.046669047558313276}, 'Levallois-Perret': {'weight': 0.05990826320300154}, 'Pantin': {'weight': 0.07468600939935167}, 'Clamart': {'weight': 0.09404786015641217}, 'LeBlanc-Mesnil': {'weight': 0.13433167906342988}, 'Bondy': {'weight': 0.13800362314084386}, 'Issy-les-Moulineaux': {'weight': 0.08280096617793631}, 'Evry': {'weight': 0.2616199533674706}, 'Chelles': {'weight': 0.26747897113605046}, 'Meudon': {'weight': 0.1084527546906935}, 'Mantes-la-Jolie': {'weight': 0.626826929861824}, 'Gennevilliers': {'weight': 0.07379024325749546}, 'Bobigny': {'weight': 0.12156479753612918}, 'Puteaux': {'weight': 0.10000000000000009}, 'Saint-Ouen': {'weight': 0.03300000000000125}, 'Vincennes': {'weight': 0.10143470806385647}, 'Garges-les-Gonesse': {'weight': 0.1305986217385169}, 'Compiegne': {'weight': 0.7433034373659284}, 'Corbeil-Essonnes': {'weight': 0.3062498979591631}, 'Saint-Germain-en-Laye': {'weight': 0.2521685943966855}, 'Chartres': {'weight': 0.9315460267748426}, 'Massy': {'weight': 0.1430244734302494}, 'Montrouge': {'weight': 0.05249761899362405}, 'Rosny-sous-Bois': {'weight': 0.1499999999999999}, 'Poissy': {'weight': 0.29059421880003145}, 'Bagneux': {'weight': 0.07468600939935167}, 'Noisy-le-Sec': {'weight': 0.13495184326269924}, 'Alfortville': {'weight': 0.10744766167767432}, 'Gagny': {'weight': 0.2006389792637514}, 'Suresnes': {'weight': 0.10000000000000009}, 'Livry-Gargan': {'weight': 0.22268587741480209}, 'Melun': {'weight': 0.47234732983261074}, 'Dreux': {'weight': 0.9752497116123646}, 'Stains': {'weight': 0.09689685237406268}, 'LaCourneuve': {'weight': 0.07071067811865764}, 'Choisy-le-Roi': {'weight': 0.13059862173851147}, 'Franconville': {'weight': 0.153153517752613}, 'Savigny-sur-Orge': {'weight': 0.20072119967755844}, 'LesMureaux': {'weight': 0.4367436318940447}, 'Bagnolet': {'weight': 0.08399999999999963}, 'Creil': {'weight': 0.4272001872658818}, 'Montigny-le-Bretonneux': {'weight': 0.3162277660168364}, 'Conflans-Sainte-Honorine': {'weight': 0.26027869678481175}, 'Neuilly-sur-Marne': {'weight': 0.2007211996775621}, 'Sainte-Genevieve-des-Bois': {'weight': 0.23399999999999466}, 'Malakoff': {'weight': 0.05990826320299847}, 'Trappes': {'weight': 0.3434312158205766}, 'Viry-Chatillon': {'weight': 0.20615528128087884}, 'Villepinte': {'weight': 0.22360679774997938}, 'Hay-les-Roses': {'weight': 0.08399999999999608}, 'Houilles': {'weight': 0.1420880009008517}, 'LeChesnay': {'weight': 0.21219802072592386}, 'Chatenay-Malabry': {'weight': 0.11981652640599669}, 'Athis-Mons': {'weight': 0.16428329190760554}, 'Saint-Cloud': {'weight': 0 ...

# %%
G.number_of_edges()
# Out:
# 38224

# %% [markdown]
# On peut utiliser les [algorithmes de networkx](https://networkx.org/documentation/stable//reference/algorithms/index.html) pour vérifier que notre graphe est connexe :

# %%
nx.is_connected(G)
# Out:
# False

# %%
list(nx.connected_components(G))
# Out:
# [{'Abbeville',
#   'Acheres',
#   'Agde',
#   'Agen',
#   'Aix-en-Provence',
#   'Aix-les-Bains',
#   'Albert',
#   'Albertville',
#   'Albi',
#   'Alencon',
#   'Ales',
#   'Alfortville',
#   'Allauch',
#   'Allonnes',
#   'Amberieu-en-Bugey',
#   'Amboise',
#   'Amiens',
#   'Andresy',
#   'Angers',
#   'Anglet',
#   'Angouleme',
#   'Annecy',
#   'Annecy-le-Vieux',
#   'Annemasse',
#   'Annonay',
#   'Antibes',
#   'Antony',
#   'Anzin',
#   'Apt',
#   'Arcachon',
#   'Arcueil',
#   'Argentan',
#   'Argenteuil',
#   'Arles',
#   'Armentieres',
#   'Arnouville-les-Gonesse',
#   'Arras',
#   'Athis-Mons',
#   'Aubagne',
#   'Aubenas',
#   'Aubergenville',
#   'Aubervilliers',
#   'Auch',
#   'Auchel',
#   'Audincourt',
#   'Aulnay-sous-Bois',
#   'Auray',
#   'Aurillac',
#   'Autun',
#   'Auxerre',
#   'Avignon',
#   'Avion',
#   'Avon',
#   'Avrille',
#   'Bagneux',
#   'Bagnolet',
#   'Bagnols-sur-Ceze',
#   'Bailleul',
#   'Bar-le-Duc',
#   'Barentin',
#   'Bayeux',
#   'Bayonne',
#   'Beaucaire',
#   'Beaune',
#   'Beausoleil',
#   'Beauvais',
#   'Begles',
#   'Behren-les-Forbach',
#   'Belfort',
#   'Bellegarde-sur-Valserine',
#   'Bergerac',
#   'Bernay',
#   "Berre-l'Etang",
#   'Besancon',
#   'Bethune',
#   'Beziers',
#   'Bezons',
#   'Biarritz',
#   'Billere',
#   'Bischheim',
#   'Bischwiller',
#   'Blagnac',
#   'Blanquefort',
#   'Blois',
#   'Bobigny',
#   'Bois-Colombes',
#   'Bois-Guillaume',
#   "Bois-d'Arcy",
#   'Boissy-Saint-Leger',
#   'Bolbec',
#   'Bollene',
#   'Bondues',
#   'Bondy',
#   'Bonneuil-sur-Marne',
#   'Bordeaux',
#   'Bouc-Bel-Air',
#   'Bouguenais',
#   'Boulogne-Billancourt',
#   'Boulogne-sur-Mer',
#   'Bourg-en-Bresse',
#   'Bourg-la-Reine',
#   'Bourg-les-Valence',
#   'Bourges',
#   'Bourgoin-Jallieu',
#   'Bressuire',
#   'Brest',
#   'Bretigny-sur-Orge',
#   'Briancon',
#   'Brie-Comte-Robert',
#   'Brignais',
#   'Brignoles',
#   'Brive-la-Gaillarde',
#   'Bron',
#   "Bruay-sur-l'Escaut",
#   'Brunoy',
#   'Bry-sur-Marne',
#   'Bully-les-Mines',
#   'Cachan',
#   'Caen',
#   'Cagnes-sur-Mer',
#   'Cahors',
#   'Calais',
#   'Caluire-et-Cuire',
#   'Cambrai',
#   'Cannes',
#   'Canteleu',
#   'Carcassonne',
#   'Carmaux',
#   'Carpentras',
#   'Carquefou',
#   'Carrieres-sous-Poissy',
#   'Carrieres-sur-Seine',
#   'Carros',
#   'Carvin',
#   'Castelnau-le-Lez',
#   'Castelnaudary',
#   'Castelsarrasin',
#   'Castres',
#   'Caudry',
#   'Cavaillon',
#   'Cenon',
#   'Cergy',
#   'Cernay',
#   'Cesson-Sevigne',
#   'Cestas',
#   'Chalette-sur-Loing',
#   'Challans',
#   'Chalon-sur-Saone',
#   'Chalons-en-Champagne',
#   'Chamalieres',
#   'Chambery',
#   'Champigny-sur-Marne',
#   'Champs-Sur-Marne',
#   'Chanteloup-les-Vignes',
#   'Chantilly',
#   'Charenton-le-Pont',
#   'Charleville-Mezieres',
#   'Chartres',
#   'Chateau-Gontier',
#   'Chateau-Thierry',
#   "Chateau-d'Olonne",
#   'Chateaubriant',
#   'Chateaudun',
#   'Chateauneuf-les-Martigues',
#   'Chateaurenard',
#   'Chateauroux',
#   'Chatellerault',
#   'Chatenay-Malabry',
#   'Chatillon',
#   'Chatou',
#   'Chaumont',
#   'Chauny',
#   'Chaville',
#   'Chelles',
#   'Chennevieres-sur-Marne',
#   'Chenove',
#   'Cherbourg',
#   'Chevilly-Larue',
#   'Chilly-Mazarin',
#   'Choisy-le-Roi',
#   'Cholet',
#   'Clamart',
#   'Clermont-Ferrand',
#   'Clichy',
#   'Clichy-sous-Bois',
#   'Cluses',
#   'Cognac',
#   'Colmar',
#   'Colombes',
#   'Colomiers',
#   'Combs-la-Ville',
#   'Comines',
#   'Compiegne',
#   'Concarneau',
#   "Conde-sur-l'Escaut",
#   'Conflans-Sainte-Honorine',
#   'Corbeil-Essonnes',
#   'Cormeilles-en-Parisis',
#   'Cosne-Cours-sur-Loire',
#   'Coudekerque-Branche',
#   'Coueron',
#   'Coulommiers',
#   'Courcouronnes',
#   "Cournon-d'Auvergne",
#   'Courrieres',
#   'Cran-Gevrier',
#   'Creil',
#   'Crepy-en-Valois',
#   'Creteil',
#   'Croix',
#   'Cugnaux',
#   'Cusset',
#   'Dax',
#   'Decines-Charpieu',
#   'Denain',
#   'Deuil-la-Barre',
#   'Deville-les-Rouen',
#   'Dieppe',
#   'Digne-Les-Bains',
#   'Digoin',
#   'Dijon',
#   'Dinan',
#   'Dole',
#   'Domont',
#   'Douai',
#   'Douarnenez',
#   'Douchy-les-Mines',
#   'Draguignan',
#   'Drancy',
#   'Draveil',
#   'Dreux',
#   'Dunkerque',
#   'Eaubonne',
#   'Echirolles',
#   'Ecully',
#   'Elancourt',
#   'Elbeuf',
#   'Enghien-les-Bains',
#   'Epernay',
#   'Epinal',
#   'Epinay-sous-Senart',
#   'Epinay-sur-Seine',
#   'Eragny',
#   'Ermont',
#   'Etampes',
#   'Etaples',
#   'Evreux',
#   'Evry',
#   'Eysines',
#   'Faches-Thumesnil',
#   'Fameck',
#   'Fecamp',
#   'Firminy',
#   'Flers',
#   'Fleury-les-Aubrais',
#   'Floirac',
#   'Florange',
#   'Fontaine',
#   'Fontainebleau',
#   'Fontenay-aux-Roses',
#   'Fontenay-le-Comte',
#   'Fontenay-le-Fleury',
#   'Fontenay-sous-Bois',
#   'Forbach',
#   'Fos-sur-Mer',
#   'Fougeres',
#   'Fourmies',
#   'Francheville',
#   'Franconville',
#   'Frejus',
#   'Fresnes',
#   'Frontignan',
#   'Gagny',
#   'Gaillac',
#   'Gap',
#   'Garches',
#   'Gardanne',
#   'Garges-les-Gonesse',
#   'Gennevilliers',
#   'Gentilly',
#   'Gien',
#   'Gif-sur-Yvette',
#   'Givors',
#   'Gonesse',
#   "Gonfreville-l'Orcher",
#   'Goussainville',
#   'Gradignan',
#   'Grande-Synthe',
#   'Granville',
#   'Grasse',
#   'Graulhet',
#   'Gravelines',
#   'Grenoble',
#   'Grigny',
#   'Guebwiller',
#   'Guerande',
#   'Gueret',
#   'Guipavas',
#   'Gujan-Mestras',
#   'Guyancourt',
#   'Haguenau',
#   'Halluin',
#   'Harnes',
#   'Haubourdin',
#   'Hautmont',
#   'Hay-les-Roses',
#   'Hayange',
#   'Hazebrouck',
#   'Hem',
#   'Hendaye',
#   'Henin-Beaumont',
#   'Hennebont',
#   'Herblay',
#   'Herouville-Saint-Clair',
#   'Hirson',
#   'Hoenheim',
#   'Houilles',
#   'Hyeres',
#   'Illkirch-Graffenstaden',
#   'Illzach',
#   'Isle-sur-la-Sorgue',
#   'Issoire',
#   'Issoudun',
#   'Issy-les-Moulineaux',
#   'Istres',
#   'Ivry-sur-Seine',
#   'Jeumont',
#   'Joinville-le-Pont',
#   'Joue-les-Tours',
#   'Jouy-le-Moutier',
#   'Juvisy-sur-Orge',
#   'Kingersheim',
#   'LaBaule-Escoublac',
#   'LaCelle-Saint-Cloud',
#   'LaChapelle-sur-Erdre',
#   'LaCiotat',
#   'LaCourneuve',
#   'LaCrau',
#   'LaFleche',
#   'LaGarenne-Colombes',
#   'LaMadeleine',
#   'LaRicamarie',
#   'LaRoche-sur-Yon',
#   'LaRochelle',
#   'LaSeyne-sur-Mer',
#   'LaTeste-de-Buch',
#   'LaTrinite',
#   'LaValette-du-Var',
#   'Lagny-sur-Marne',
#   'Lambersart',
#   'Landerneau',
#   'Lanester',
#   'Lannion',
#   'Laon',
#   'Lattes',
#   'Laval',
#   'Laxou',
#   'LeBlanc-Mesnil',
#   'LeBourget',
#   'LeBouscat',
#   'LeCannet',
#   'LeChambon-Feugerolles',
#   'LeChesnay',
#   'LeCreusot',
#   'LeGrand-Quevilly',
#   'LeHavre',
#   'LeKremlin-Bicetre',
#   'LeMans',
#   'LeMee-sur-Seine',
#   'LePecq',
#   'LePerreux-Sur-Marne',
#   'LePetit-Quevilly',
#   'LePlessis-Robinson',
#   'LePlessis-Trevise',
#   'LePont-de-Claix',
#   'LePontet',
#   'LePortel',
#   'LePre-Saint-Gervais',
#   'LePuy-en-Velay',
#   'LeRaincy',
#   'LeRelecq-Kerhuon',
#   'LeVesinet',
#   'Lens',
#   'Les-Pennes-Mirabeau',
#   'LesClayes-sous-Bois',
#   'LesHerbiers',
#   'LesLilas',
#   'LesMureaux',
#   'LesPavillons-sous-Bois',
#   'LesPonts-de-Ce',
#   "LesSables-d'Olonne",
#   'Levallois-Perret',
#   'Libourne',
#   'Lievin',
#   'Lille',
#   'Limay',
#   'Limeil-Brevannes',
#   'Limoges',
#   'Lingolsheim',
#   'Lisieux',
#   'Livry-Gargan',
#   'Lognes',
#   'Lomme',
#   'Longjumeau',
#   'Longuenesse',
#   'Longwy',
#   'Lons-le-Saunier',
#   'Loos',
#   'Lorient',
#   'Lormont',
#   'Lourdes',
#   'Louviers',
#   'Luce',
#   'Lunel',
#   'Luneville',
#   'Lyon',
#   'Macon',
#   'Maisons-Alfort',
#   'Maisons-Laffitte',
#   'Malakoff',
#   'Mandelieu-la-Napoule',
#   'Manosque',
#   'Mantes-la-Jolie',
#   'Mantes-la-Ville',
#   'Marcq-en-Baroeul',
#   'Marignane',
#   'Marly',
#   'Marly-le-Roi',
#   'Marmande',
#   'Maromme',
#   'Marseille',
#   'Martigues',
#   'Massy',
#   'Maubeuge',
#   'Mauguio',
#   'Maurepas',
#   'Mayenne',
#   'Mazamet',
#   'Meaux',
#   'Melun',
#   'Mende',
#   'Mennecy',
#   'Menton',
#   'Mericourt',
#   'Merignac',
#   'Meru',
#   'Metz',
#   'Meudon',
#   'Meylan',
#   'Meyzieu',
#   'Millau',
#   'Miramas',
#   'Mitry-Mory',
#   'Moissac',
#   'Moissy-Cramayel',
#   'Mont-Saint-Aignan',
#   'Mont-de-Marsan',
#   'Montargis',
#   'Montataire',
#   'Montauban',
#   'Montbeliard',
#   'Montbrison',
#   'Montceau-les-Mines',
#   'Montelimar',
#   'Montereau-faut-Yonne',
#   'Montesson',
#   'Montfermeil',
#   'Montgeron',
#   'Montigny-en-Gohelle',
#   'Montigny-le-Bretonneux',
#   'Montigny-les-Cormeilles',
#   'Montigny-les-Metz',
#   'Montivilliers',
#   'Montlucon',
#   'Montmagny',
#   'Montmorency',
#   'Montpellier',
#   'Montreuil',
#   'Montrouge',
#   'Morangis',
#   'Morlaix',
#   'Morsang-sur-Orge',
#   'Mougins',
#   'Moulins',
#   'Mouvaux',
#   'Mulhouse',
#   'Muret',
#   'Nancy',
#   'Nanterre',
#   'Nantes',
#   'Narbonne',
#   'Nemours',
#   'Neuilly-Plaisance',
#   'Neuilly-sur-Marne',
#   'Neuilly-sur-Seine',
#   'Nevers',
#   'Nice',
#   'Nimes',
#   'Niort',
#   'Noeux-les-Mines',
#   'Nogent-le-Rotrou',
#   'Nogent-sur-Marne',
#   'Nogent-sur-Oise',
#   'Noisiel',
#   'Noisy-le-Grand',
#   'Noisy-le-Sec',
#   'Noyon',
#   'Octeville',
#   'Oignies',
#   'Oissel',
#   'Olivet',
#   'Ollioules',
#   'Oloron-Sainte-Marie',
#   'Orange',
#   'Orleans',
#   'Orly',
#   'Ormesson-sur-Marne',
#   'Orsay',
#   'Orthez',
#   'Orvault',
#   'Osny',
#   'Ostwald',
#   'Oullins',
#   'Outreau',
#   'Oyonnax',
#   'Ozoir-la-Ferriere',
#   'Palaiseau',
#   'Pamiers',
#   'Pantin',
#   'Paris',
#   'Parthenay',
#   'Pau',
#   'Perigueux',
#   'Perpignan',
#   'Persan',
#   'Pertuis',
#   'Pessac',
#   'Pierrefitte-sur-Seine',
#   'Pierrelatte',
#   'Plaisance-du-Touch',
#   'Plaisir',
#   'Plerin',
#   'Ploemeur',
#   'Ploufragan',
#   'Plougastel-Daoulas',
#   'Plouzane',
#   'Poissy',
#   'Poitiers',
#   'Pont-Sainte-Maxence',
#   'Pont-a-Mousson',
#   'Pontarlier',
#   'Pontivy',
#   'Pontoise',
#   'Port-de-Bouc',
#   'Privas',
#   'Provins',
#   'Puteaux',
#   'Quimper',
#   'Quimperle',
#   'Raismes',
#   'Rambouillet',
#   'Ramonville-Saint-Agne',
#   'Reims',
#   'Rennes',
#   'Reze',
#   'Riedisheim',
#   'Rillieux-La-Pape',
#   'Riom',
#   'Ris-Orangis',
#   'Rive-de-Gier',
#   'Rixheim',
#   'Roanne',
#   'Roche-la-Moliere',
#   'Rochefort',
#   'Rodez',
#   'Rognac',
#   'Roissy-en-Brie',
#   'Romainville',
#   'Romans-sur-Isere',
#   'Rombas',
#   'Romilly-sur-Seine',
#   'Romorantin-Lanthenay',
#   'Ronchin',
#   'Roncq',
#   'Roquebrune-Cap-Martin',
#   'Roquebrune-surArgens',
#   'Rosny-sous-Bois',
#   'Roubaix',
#   'Rouen',
#   'Royan',
#   'Rueil-Malmaison',
#   'Sable-sur-Sarthe',
#   'Saint-Amand-Montrond',
#   'Saint-Amand-les-Eaux',
#   'Saint-Andre-les-Vergers',
#   'Saint-Avertin',
#   'Saint-Avold',
#   'Saint-Brice-sous-Foret',
#   'Saint-Brieuc',
#   'Saint-Chamond',
#   'Saint-Claude',
#   'Saint-Cloud',
#   "Saint-Cyr-l'Ecole",
#   'Saint-Cyr-sur-Loire',
#   'Saint-Denis',
#   'Saint-Die',
#   'Saint-Dizier',
#   'Saint-Etienne',
#   'Saint-Etienne-du-Rouvray',
#   'Saint-Fargeau-Ponthierry',
#   'Saint-Fons',
#   'Saint-Gaudens',
#   'Saint-Genis-Laval',
#   'Saint-Germain-en-Laye',
#   'Saint-Gilles',
#   'Saint-Gratien',
#   'Saint-Herblain',
#   'Saint-Jean-de-Braye',
#   'Saint-Jean-de-Luz',
#   'Saint-Jean-de-la-Ruelle',
#   'Saint-Junien',
#   'Saint-Laurent-du-Var',
#   'Saint-Leu-la-Foret',
#   'Saint-Lo',
#   'Saint-Louis',
#   'Saint-Malo',
#   'Saint-Mande',
#   'Saint-Martin-Boulogne',
#   "Saint-Martin-d'Heres",
#   'Saint-Martin-de-Crau',
#   'Saint-Maur-des-Fosses',
#   'Saint-Maurice',
#   'Saint-Max',
#   'Saint-Medard-en-Jalles',
#   'Saint-Michel-sur-Orge',
#   'Saint-Nazaire',
#   'Saint-Omer',
#   'Saint-Ouen',
#   "Saint-Ouen-l'Aumone",
#   'Saint-Pierre-des-Corps',
#   'Saint-Pol-sur-Mer',
#   'Saint-Priest',
#   'Saint-Quentin',
#   'Saint-Raphael',
#   'Saint-Saulve',
#   'Saint-Sebastien-sur-Loire',
#   'Sainte-Foy-les-Lyon',
#   'Sainte-Genevieve-des-Bois',
#   'Sainte-Maxime',
#   'Saintes',
#   'Sallanches',
#   'Sallaumines',
#   'Salon-de-Provence',
#   'Sanary-sur-Mer',
#   'Sannois',
#   'Saran',
#   'Sarcelles',
#   'Sarrebourg',
#   'Sarreguemines',
#   'Sartrouville',
#   'Saumur',
#   'Saverne',
#   'Savigny-le-Temple',
#   'Savigny-sur-Orge',
#   'Sceaux',
#   'Schiltigheim',
#   'Seclin',
#   'Sedan',
#   'Selestat',
#   'Senlis',
#   'Sens',
#   'Septemes-les-Vallons',
#   'Sete',
#   'Sevran',
#   'Sevres',
#   'Seynod',
#   'Seyssinet-Pariset',
#   'Sin-le-Noble',
#   'Soissons',
#   'Soisy-sous-Montmorency',
#   'Somain',
#   'Sorgues',
#   'Sotteville-les-Rouen',
#   'Soyaux',
#   'Stains',
#   'Stiring-Wendel',
#   'Strasbourg',
#   'Sucy-en-Brie',
#   'Suresnes',
#   'Talant',
#   'Talence',
#   'Tarare',
#   'Tarascon',
#   'Tarbes',
#   'Tassin-la-Demi-Lune',
#   'Taverny',
#   'Tergnier',
#   'Thiais',
#   'Thiers',
#   'Thionville',
#   'Thonon-les-Bains',
#   'Thouars',
#   'Tinqueux',
#   'Torcy',
#   'Toul',
#   'Toulon',
#   'Toulouse',
#   'Tourcoing',
#   'Tourlaville',
#   'Tournefeuille',
#   'Tours',
#   'Trappes',
#   'Trelaze',
#   'Troyes',
#   'Tulle',
#   'Union',
#   'Ussel',
#   'Vaires-sur-Marne',
#   'Valence',
#   'Valenciennes',
#   'Valentigney',
#   'Valenton',
#   'Vallauris',
#   'Vandoeuvre-les-Nancy',
#   'Vannes',
#   'Vanves',
#   'Vaulx-en-Velin',
#   'Vaureal',
#   'Vauvert',
#   'Velizy-Villacoublay',
#   'Vence',
#   'Vendome',
#   'Venissieux',
#   'Verneuil-sur-Seine',
#   'Vernon',
#   'Vernouillet',
#   'Verrieres-le-Buisson',
#   'Versailles',
#   'Vertou',
#   'Vesoul',
#   'Vichy',
#   'Vienne',
#   'Vierzon',
#   'VieuxConde',
#   'Vigneux-sur-Seine',
#   "Ville-d'Avray",
#   'Villefontaine',
#   'Villefranche-de-Rouergue',
#   'Villefranche-sur-Saone',
#   'Villejuif',
#   'Villemomble',
#   "Villenave-d'Ornon",
#   'Villeneuve-Loubet',
#   'Villeneuve-Saint-Georges',
#   "Villeneuve-d'Ascq",
#   'Villeneuve-la-Garenne',
#   'Villeneuve-le-Roi',
#   'Villeneuve-sur-Lot',
#   'Villeparisis',
#   'Villepinte',
#   'Villers-les-Nancy',
#   'Villerupt',
#   'Villetaneuse',
#   'Villeurbanne',
#   'Villiers-le-Bel',
#   'Villiers-sur-Marne',
#   'Vincennes',
#   'Vire',
#   'Viroflay',
#   'Viry-Chatillon',
#   'Vitre',
#   'Vitrolles',
#   'Vitry-le-Francois',
#   'Vitry-sur-Seine',
#   'Voiron',
#   'Voisins-le-Bretonneux',
#   'Wasquehal',
#   'Wattignies',
#   'Wattrelos',
#   'Wittelsheim',
#   'Wittenheim',
#   'Woippy',
#   'Yerres',
#   'Yvetot',
#   'Yzeure'},
#  {'Ajaccio'},
#  {'Bastia'}]

# %% [markdown]
# ## dessin du graphe

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# On a les sommets :

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 

graphe.plot(ax=ax)

plt.show()

# %% [markdown]
# On crée le geodataframe des arêtes :

# %%
from shapely.geometry import LineString

# %%
rows = []
for (u, v) in G.edges:
    p1 = graphe[graphe["nom"] == u].geometry.iloc[0]
    p2 = graphe[graphe["nom"] == v].geometry.iloc[0]
    
    row = {'orig': u, 
           'dest': v,
           'geometry': LineString([p1, p2])}
    rows.append(row)

# %%
gdf = gpd.GeoDataFrame(rows, crs="EPSG:4326")

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 

gdf.plot(ax=ax)

plt.show()
